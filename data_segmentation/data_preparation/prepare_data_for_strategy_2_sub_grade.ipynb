# %%
import pandas as pd

# %%
name = 'use_p2p_lendingclub_filtered_sorted_by_issue_d_and_then_id_70_percent.csv'

train = pd.read_csv('./data/strategy_2/' + name)

print(train.shape)

test = pd.read_csv('./data/strategy_2/use_p2p_lendingclub_filtered_sorted_by_issue_d_and_then_id_30_percent.csv')

print(test.shape)
# Out:
# (404831, 134)
# (173500, 134)

# %%
dummy_columns = [col for col in train.columns.tolist() if 'sub_grade' in col]
sorted(dummy_columns)
print(dummy_columns)
# Out:
# ['sub_grade_A1', 'sub_grade_A2', 'sub_grade_A3', 'sub_grade_A4', 'sub_grade_A5', 'sub_grade_B1', 'sub_grade_B2', 'sub_grade_B3', 'sub_grade_B4', 'sub_grade_B5', 'sub_grade_C1', 'sub_grade_C2', 'sub_grade_C3', 'sub_grade_C4', 'sub_grade_C5', 'sub_grade_D1', 'sub_grade_D2', 'sub_grade_D3', 'sub_grade_D4', 'sub_grade_D5', 'sub_grade_E1', 'sub_grade_E2', 'sub_grade_E3', 'sub_grade_E4', 'sub_grade_E5', 'sub_grade_F1', 'sub_grade_F2', 'sub_grade_F3', 'sub_grade_F4', 'sub_grade_F5', 'sub_grade_G1', 'sub_grade_G2', 'sub_grade_G3', 'sub_grade_G4']

# %%
sub_grades = [col[10:len(col)+1] for col in dummy_columns]

# %%
print(sub_grades)
# Out:
# ['A1', 'A2', 'A3', 'A4', 'A5', 'B1', 'B2', 'B3', 'B4', 'B5', 'C1', 'C2', 'C3', 'C4', 'C5', 'D1', 'D2', 'D3', 'D4', 'D5', 'E1', 'E2', 'E3', 'E4', 'E5', 'F1', 'F2', 'F3', 'F4', 'F5', 'G1', 'G2', 'G3', 'G4']

# %%
print(len(sub_grades))
# Out:
# 34

# %%
train_names = []

length = []

for value, sub_grade in zip(dummy_columns, sub_grades):
    
    sub_grade_df = train[train[value] == 1]
    
    name = 'train_' + sub_grade + '_one_hot_encoded'
    train_names.append(name)
    
    #if len(sub_grade_df.index)>20240:
        #sub_grade_df = sub_grade_df.sample(n = 20240, random_state = 20461)
    
    print(sub_grade_df.shape)
    
    defaulters = len(sub_grade_df[sub_grade_df.loan_status == 1].index)
    non_defaulters = len(sub_grade_df[sub_grade_df.loan_status == 0].index)
    
    print(sub_grade)
    
    print(str((defaulters/(non_defaulters + defaulters)) * 100), '% defaulters')
    
    sub_grade_df.to_csv('./data/strategy_2/' + name + '.csv', index = False)
    
    length.append(len(sub_grade_df.index))

rows = []

is_last = True
for index, row in train.iterrows():
    for sub_grade in dummy_columns:
        if row[sub_grade] == 1:
            is_last = False
            break
    if is_last is True:
        rows.append(row.tolist())
        
    is_last = True
    
last_set = pd.DataFrame(data = rows, columns = test.columns)

length.append(len(last_set.index))

name = 'train_G5_one_hot_encoded'
train_names.append(name)

#if len(last_set.index)>20240:
    #last_set = last_set.sample(n = 20240, random_state = 20461)

defaulters = len(last_set[last_set.loan_status == 1].index)
non_defaulters = len(last_set[last_set.loan_status == 0].index)

print(last_set.shape)

print(str((defaulters/(non_defaulters + defaulters)) * 100), '% defaulters')

last_set.to_csv('./data/strategy_2/' + name + '.csv', index = False)

length.append(len(last_set.index))

print(last_set.shape)
import numpy as np
print(np.cumsum(length))
# Out:
# (9367, 134)
# A1
# 3.0532721255471333 % defaulters
# (9986, 134)
# A2
# 4.826757460444623 % defaulters
# (11562, 134)
# A3
# 5.379692094793288 % defaulters
# (17491, 134)
# A4
# 6.872105654336516 % defaulters
# (19948, 134)
# A5
# 8.552235813114097 % defaulters
# (20549, 134)
# B1
# 9.596574042532485 % defaulters
# (24299, 134)
# B2
# 10.691798016379275 % defaulters
# (28808, 134)
# B3
# 12.073035267981117 % defaulters
# (27409, 134)
# B4
# 13.703528038235616 % defaulters
# (22797, 134)
# B5
# 15.567837873404395 % defaulters
# (23863, 134)
# C1
# 17.252650546871724 % defaulters
# (22929, 134)
# C2
# 19.324872432290984 % defaulters
# (21121, 134)
# C3
# 21.504663604942948 % defaulters
# (19818, 134)
# C4
# 23.35755373902513 % defaulters
# (18198, 134)
# C5
# 24.370809979118587 % defaulters
# (15848, 134)
# D1
# 25.763503281171126 % defaulters
# (14343, 134)
# D2
# 27.14215993864603 % defaulters
# (12406, 134)
# D3
# 27.599548605513462 % defaulters
# (11594, 134)
# D4
# 30.35190615835777 % defaulters
# (9521, 134)
# D5
# 31.173196092847387 % defaulters
# (7363, 134)
# E1
# 34.29308705690615 % defaulters
# (7093, 134)
# E2
# 35.739461440857184 % defaulters
# (5705, 134)
# E3
# 37.090271691498685 % defaulters
# (4952, 134)
# E4
# 38.52988691437803 % defaulters
# (4207, 134)
# E5
# 39.88590444497267 % defaulters
# (3287, 134)
# F1
# 38.94128384545178 % defaulters
# (2458, 134)
# F2
# 41.29373474369406 % defaulters
# (2232, 134)
# F3
# 42.562724014336915 % defaulters
# (1676, 134)
# F4
# 45.22673031026253 % defaulters
# (1286, 134)
# F5
# 45.25660964230171 % defaulters
# (946, 134)
# G1
# 47.780126849894295 % defaulters
# (679, 134)
# G2
# 45.21354933726068 % defaulters
# (484, 134)
# G3
# 48.34710743801653 % defaulters
# (333, 134)
# G4
# 42.34234234234234 % defaulters
# (273, 134)
# 49.45054945054945 % defaulters
# (273, 134)
# [  9367  19353  30915  48406  68354  88903 113202 142010 169419 192216
#  216079 239008 260129 279947 298145 313993 328336 340742 352336 361857
#  369220 376313 382018 386970 391177 394464 396922 399154 400830 402116
#  403062 403741 404225 404558 404831 405104]

# %%
dummy_columns = [col for col in test.columns.tolist() if 'sub_grade' in col]
sorted(dummy_columns)
print(dummy_columns)
# Out:
# ['sub_grade_A1', 'sub_grade_A2', 'sub_grade_A3', 'sub_grade_A4', 'sub_grade_A5', 'sub_grade_B1', 'sub_grade_B2', 'sub_grade_B3', 'sub_grade_B4', 'sub_grade_B5', 'sub_grade_C1', 'sub_grade_C2', 'sub_grade_C3', 'sub_grade_C4', 'sub_grade_C5', 'sub_grade_D1', 'sub_grade_D2', 'sub_grade_D3', 'sub_grade_D4', 'sub_grade_D5', 'sub_grade_E1', 'sub_grade_E2', 'sub_grade_E3', 'sub_grade_E4', 'sub_grade_E5', 'sub_grade_F1', 'sub_grade_F2', 'sub_grade_F3', 'sub_grade_F4', 'sub_grade_F5', 'sub_grade_G1', 'sub_grade_G2', 'sub_grade_G3', 'sub_grade_G4']

# %%
sub_grades = [col[10:len(col)+1] for col in dummy_columns]

# %%
print(sub_grades)
# Out:
# ['A1', 'A2', 'A3', 'A4', 'A5', 'B1', 'B2', 'B3', 'B4', 'B5', 'C1', 'C2', 'C3', 'C4', 'C5', 'D1', 'D2', 'D3', 'D4', 'D5', 'E1', 'E2', 'E3', 'E4', 'E5', 'F1', 'F2', 'F3', 'F4', 'F5', 'G1', 'G2', 'G3', 'G4']

# %%
print(len(sub_grades))
# Out:
# 34

# %%
test_names = []

length = []

for value, sub_grade in zip(dummy_columns, sub_grades):
    
    sub_grade_df = test[test[value] == 1]
    
    name = 'test_' + sub_grade + '_one_hot_encoded'
    test_names.append(name)
    
    print(sub_grade_df.shape)
    
    sub_grade_df.to_csv('./data/strategy_2/' + name + '.csv', index = False)
    
    length.append(len(sub_grade_df.index))

rows = []

is_last = True
for index, row in test.iterrows():
    for sub_grade in dummy_columns:
        if row[sub_grade] == 1:
            is_last = False
            break
    if is_last is True:
        rows.append(row.tolist())
        
    is_last = True
    
last_set = pd.DataFrame(data = rows, columns = test.columns)

length.append(len(last_set.index))

name = 'test_G5_one_hot_encoded'
test_names.append(name)
last_set.to_csv('./data/strategy_2/' + name + '.csv', index = False)
print(last_set.shape)
import numpy as np
print(np.cumsum(length))
# Out:
# (4960, 134)
# (3995, 134)
# (3749, 134)
# (5338, 134)
# (7294, 134)
# (7710, 134)
# (8204, 134)
# (9154, 134)
# (9627, 134)
# (9903, 134)
# (10876, 134)
# (10389, 134)
# (10114, 134)
# (10304, 134)
# (8753, 134)
# (7316, 134)
# (5932, 134)
# (5207, 134)
# (5316, 134)
# (4626, 134)
# (4338, 134)
# (3769, 134)
# (3432, 134)
# (2892, 134)
# (2502, 134)
# (1890, 134)
# (1475, 134)
# (1109, 134)
# (912, 134)
# (773, 134)
# (550, 134)
# (419, 134)
# (296, 134)
# (207, 134)
# (169, 134)
# [  4960   8955  12704  18042  25336  33046  41250  50404  60031  69934
#   80810  91199 101313 111617 120370 127686 133618 138825 144141 148767
#  153105 156874 160306 163198 165700 167590 169065 170174 171086 171859
#  172409 172828 173124 173331 173500]

# %%
info = pd.DataFrame({'train_names': train_names, 'test_names': test_names})
info.to_csv('./data/strategy_2/info.csv', index = False)

# %%
info
# Out:
#                  train_names               test_names
# 0   train_A1_one_hot_encoded  test_A1_one_hot_encoded
# 1   train_A2_one_hot_encoded  test_A2_one_hot_encoded
# 2   train_A3_one_hot_encoded  test_A3_one_hot_encoded
# 3   train_A4_one_hot_encoded  test_A4_one_hot_encoded
# 4   train_A5_one_hot_encoded  test_A5_one_hot_encoded
# 5   train_B1_one_hot_encoded  test_B1_one_hot_encoded
# 6   train_B2_one_hot_encoded  test_B2_one_hot_encoded
# 7   train_B3_one_hot_encoded  test_B3_one_hot_encoded
# 8   train_B4_one_hot_encoded  test_B4_one_hot_encoded
# 9   train_B5_one_hot_encoded  test_B5_one_hot_encoded
# 10  train_C1_one_hot_encoded  test_C1_one_hot_encoded
# 11  train_C2_one_hot_encoded  test_C2_one_hot_encoded
# 12  train_C3_one_hot_encoded  test_C3_one_hot_encoded
# 13  train_C4_one_hot_encoded  test_C4_one_hot_encoded
# 14  train_C5_one_hot_encoded  test_C5_one_hot_encoded
# 15  train_D1_one_hot_encoded  test_D1_one_hot_encoded
# 16  train_D2_one_hot_encoded  test_D2_one_hot_encoded
# 17  train_D3_one_hot_encoded  test_D3_one_hot_encoded
# 18  train_D4_one_hot_encoded  test_D4_one_hot_encoded
# 19  train_D5_one_hot_encoded  test_D5_one_hot_encoded
# 20  train_E1_one_hot_encoded  test_E1_one_hot_encoded
# 21  train_E2_one_hot_encoded  test_E2_one_hot_encoded
# 22  train_E3_one_hot_encoded  test_E3_one_hot_encoded
# 23  train_E4_one_hot_encoded  test_E4_one_hot_encoded
# 24  train_E5_one_hot_encoded  test_E5_one_hot_encoded
# 25  train_F1_one_hot_encoded  test_F1_one_hot_encoded
# 26  train_F2_one_hot_encoded  test_F2_one_hot_encoded
# 27  train_F3_one_hot_encoded  test_F3_one_hot_encoded
# 28  train_F4_one_hot_encoded  test_F4_one_hot_encoded
# 29  train_F5_one_hot_encoded  test_F5_one_hot_encoded
# 30  train_G1_one_hot_encoded  test_G1_one_hot_encoded
# 31  train_G2_one_hot_encoded  test_G2_one_hot_encoded
# 32  train_G3_one_hot_encoded  test_G3_one_hot_encoded
# 33  train_G4_one_hot_encoded  test_G4_one_hot_encoded
# 34  train_G5_one_hot_encoded  test_G5_one_hot_encoded
