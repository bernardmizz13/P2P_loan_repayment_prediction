# %%
import pandas as pd

# %%
name = 'use_p2p_lendingclub_filtered_sorted_by_issue_d_and_then_id_70_percent.csv'

train = pd.read_csv('./data/strategy_2/' + name)

print(train.shape)

test = pd.read_csv('./data/strategy_2/use_p2p_lendingclub_filtered_sorted_by_issue_d_and_then_id_30_percent.csv')

print(test.shape)
# Out:
# (404831, 134)
# (173500, 134)

# %%
dummy_columns = [col for col in train.columns.tolist() if 'addr_state' in col]
sorted(dummy_columns)
print(dummy_columns)
print(len(dummy_columns))
# Out:
# ['addr_state_AK', 'addr_state_AL', 'addr_state_AR', 'addr_state_AZ', 'addr_state_CA', 'addr_state_CO', 'addr_state_CT', 'addr_state_DC', 'addr_state_DE', 'addr_state_FL', 'addr_state_GA', 'addr_state_HI', 'addr_state_IA', 'addr_state_ID', 'addr_state_IL', 'addr_state_IN', 'addr_state_KS', 'addr_state_KY', 'addr_state_LA', 'addr_state_MA', 'addr_state_MD', 'addr_state_ME', 'addr_state_MI', 'addr_state_MN', 'addr_state_MO', 'addr_state_MS', 'addr_state_MT', 'addr_state_NC', 'addr_state_ND', 'addr_state_NE', 'addr_state_NH', 'addr_state_NJ', 'addr_state_NM', 'addr_state_NV', 'addr_state_NY', 'addr_state_OH', 'addr_state_OK', 'addr_state_OR', 'addr_state_PA', 'addr_state_RI', 'addr_state_SC', 'addr_state_SD', 'addr_state_TN', 'addr_state_TX', 'addr_state_UT', 'addr_state_VA', 'addr_state_VT', 'addr_state_WA', 'addr_state_WI', 'addr_state_WV']
# 50

# %%
sub_grades = [col[11:len(col)+1] for col in dummy_columns]

# %%
print(sub_grades)
# Out:
# ['AK', 'AL', 'AR', 'AZ', 'CA', 'CO', 'CT', 'DC', 'DE', 'FL', 'GA', 'HI', 'IA', 'ID', 'IL', 'IN', 'KS', 'KY', 'LA', 'MA', 'MD', 'ME', 'MI', 'MN', 'MO', 'MS', 'MT', 'NC', 'ND', 'NE', 'NH', 'NJ', 'NM', 'NV', 'NY', 'OH', 'OK', 'OR', 'PA', 'RI', 'SC', 'SD', 'TN', 'TX', 'UT', 'VA', 'VT', 'WA', 'WI', 'WV']

# %%
print(len(sub_grades))
# Out:
# 50

# %%
train_names = []

length = []

for value, sub_grade in zip(dummy_columns, sub_grades):
    
    sub_grade_df = train[train[value] == 1]
    
    name = 'train_' + sub_grade + '_one_hot_encoded'
    train_names.append(name)
    
    if len(sub_grade_df.index)>20240:
        sub_grade_df = sub_grade_df.sample(n = 20240, random_state = 20461)
    
    print(sub_grade)
        
    print(sub_grade_df.shape)
    
    if len(sub_grade_df.index)>0:
        defaulters = len(sub_grade_df[sub_grade_df.loan_status == 1].index)
        non_defaulters = len(sub_grade_df[sub_grade_df.loan_status == 0].index)
        print(str((defaulters/(non_defaulters + defaulters)) * 100), '% defaulters')
    
    sub_grade_df.to_csv('./data/strateg_2_addr_state/' + name + '.csv', index = False)
    
    length.append(len(sub_grade_df.index))

rows = []

is_last = True
for index, row in train.iterrows():
    for sub_grade in dummy_columns:
        if row[sub_grade] == 1:
            is_last = False
            break
    if is_last is True:
        rows.append(row.tolist())
        
    is_last = True
    
last_set = pd.DataFrame(data = rows, columns = test.columns)

name = 'train_WY_one_hot_encoded'
train_names.append(name)

#if len(last_set.index)>20240:
    #last_set = last_set.sample(n = 20240, random_state = 20461)

defaulters = len(last_set[last_set.loan_status == 1].index)
non_defaulters = len(last_set[last_set.loan_status == 0].index)

last_set.to_csv('./data/strateg_2_addr_state/' + name + '.csv', index = False)

length.append(len(last_set.index))

print('WY')

print(last_set.shape)
print(str((defaulters/(non_defaulters + defaulters)) * 100), '% defaulters')

import numpy as np
print(np.cumsum(length))
# Out:
# AK
# (1111, 134)
# 16.831683168316832 % defaulters
# AL
# (5031, 134)
# 22.301729278473463 % defaulters
# AR
# (2931, 134)
# 21.119071989082226 % defaulters
# AZ
# (9666, 134)
# 18.746120422098077 % defaulters
# CA
# (20240, 134)
# 17.75691699604743 % defaulters
# CO
# (8863, 134)
# 15.0062055737335 % defaulters
# CT
# (5965, 134)
# 17.300922045264038 % defaulters
# DC
# (1277, 134)
# 11.667971808927174 % defaulters
# DE
# (1040, 134)
# 20.192307692307693 % defaulters
# FL
# (20240, 134)
# 20.518774703557312 % defaulters
# GA
# (12870, 134)
# 17.544677544677544 % defaulters
# HI
# (2215, 134)
# 19.63882618510158 % defaulters
# IA
# (7, 134)
# 14.285714285714285 % defaulters
# ID
# (9, 134)
# 11.11111111111111 % defaulters
# IL
# (15497, 134)
# 17.12589533458089 % defaulters
# IN
# (5399, 134)
# 21.652157807001295 % defaulters
# KS
# (3550, 134)
# 15.549295774647886 % defaulters
# KY
# (3691, 134)
# 19.479815768084528 % defaulters
# LA
# (4776, 134)
# 20.85427135678392 % defaulters
# MA
# (9549, 134)
# 17.802911299612525 % defaulters
# MD
# (9390, 134)
# 19.69116080937167 % defaulters
# ME
# (4, 134)
# 0.0 % defaulters
# MI
# (10000, 134)
# 19.48 % defaulters
# MN
# (7238, 134)
# 18.541033434650455 % defaulters
# MO
# (6461, 134)
# 20.739823556724964 % defaulters
# MS
# (850, 134)
# 29.411764705882355 % defaulters
# MT
# (1215, 134)
# 15.967078189300413 % defaulters
# NC
# (11043, 134)
# 19.922122611609165 % defaulters
# ND
# (0, 134)
# NE
# (8, 134)
# 62.5 % defaulters
# NH
# (1832, 134)
# 13.646288209606988 % defaulters
# NJ
# (15285, 134)
# 19.74484789008832 % defaulters
# NM
# (2273, 134)
# 20.633523977122746 % defaulters
# NV
# (5939, 134)
# 22.124936858056913 % defaulters
# NY
# (20240, 134)
# 20.711462450592887 % defaulters
# OH
# (12784, 134)
# 20.126720901126408 % defaulters
# OK
# (3565, 134)
# 21.711079943899016 % defaulters
# OR
# (5402, 134)
# 15.938541281007035 % defaulters
# PA
# (13878, 134)
# 19.786712782821734 % defaulters
# RI
# (1722, 134)
# 18.81533101045296 % defaulters
# SC
# (4616, 134)
# 16.65944540727903 % defaulters
# SD
# (866, 134)
# 20.323325635103924 % defaulters
# TN
# (4916, 134)
# 22.945484133441823 % defaulters
# TX
# (20240, 134)
# 17.16403162055336 % defaulters
# UT
# (3220, 134)
# 18.074534161490682 % defaulters
# VA
# (12326, 134)
# 19.51160149277949 % defaulters
# VT
# (713, 134)
# 15.427769985974754 % defaulters
# WA
# (9375, 134)
# 16.448 % defaulters
# WI
# (5088, 134)
# 17.531446540880502 % defaulters
# WV
# (1924, 134)
# 15.54054054054054 % defaulters
# WY
# (969, 134)
# 16.202270381836943 % defaulters
# [  1111   6142   9073  18739  38979  47842  53807  55084  56124  76364
#   89234  91449  91456  91465 106962 112361 115911 119602 124378 133927
#  143317 143321 153321 160559 167020 167870 169085 180128 180128 180136
#  181968 197253 199526 205465 225705 238489 242054 247456 261334 263056
#  267672 268538 273454 293694 296914 309240 309953 319328 324416 326340
#  327309]

# %%
dummy_columns = [col for col in test.columns.tolist() if 'addr_state' in col]
sorted(dummy_columns)
print(dummy_columns)
# Out:
# ['addr_state_AK', 'addr_state_AL', 'addr_state_AR', 'addr_state_AZ', 'addr_state_CA', 'addr_state_CO', 'addr_state_CT', 'addr_state_DC', 'addr_state_DE', 'addr_state_FL', 'addr_state_GA', 'addr_state_HI', 'addr_state_IA', 'addr_state_ID', 'addr_state_IL', 'addr_state_IN', 'addr_state_KS', 'addr_state_KY', 'addr_state_LA', 'addr_state_MA', 'addr_state_MD', 'addr_state_ME', 'addr_state_MI', 'addr_state_MN', 'addr_state_MO', 'addr_state_MS', 'addr_state_MT', 'addr_state_NC', 'addr_state_ND', 'addr_state_NE', 'addr_state_NH', 'addr_state_NJ', 'addr_state_NM', 'addr_state_NV', 'addr_state_NY', 'addr_state_OH', 'addr_state_OK', 'addr_state_OR', 'addr_state_PA', 'addr_state_RI', 'addr_state_SC', 'addr_state_SD', 'addr_state_TN', 'addr_state_TX', 'addr_state_UT', 'addr_state_VA', 'addr_state_VT', 'addr_state_WA', 'addr_state_WI', 'addr_state_WV']

# %%
sub_grades = [col[11:len(col)+1] for col in dummy_columns]

# %%
print(sub_grades)
# Out:
# ['AK', 'AL', 'AR', 'AZ', 'CA', 'CO', 'CT', 'DC', 'DE', 'FL', 'GA', 'HI', 'IA', 'ID', 'IL', 'IN', 'KS', 'KY', 'LA', 'MA', 'MD', 'ME', 'MI', 'MN', 'MO', 'MS', 'MT', 'NC', 'ND', 'NE', 'NH', 'NJ', 'NM', 'NV', 'NY', 'OH', 'OK', 'OR', 'PA', 'RI', 'SC', 'SD', 'TN', 'TX', 'UT', 'VA', 'VT', 'WA', 'WI', 'WV']

# %%
print(len(sub_grades))
# Out:
# 50

# %%
test_names = []

length = []

for value, sub_grade in zip(dummy_columns, sub_grades):
    
    sub_grade_df = test[test[value] == 1]
    
    name = 'test_' + sub_grade + '_one_hot_encoded'
    test_names.append(name)
    
    print(sub_grade)
    print(sub_grade_df.shape)
    
    sub_grade_df.to_csv('./data/strateg_2_addr_state/' + name + '.csv', index = False)
    
    length.append(len(sub_grade_df.index))

rows = []

is_last = True
for index, row in test.iterrows():
    for sub_grade in dummy_columns:
        if row[sub_grade] == 1:
            is_last = False
            break
    if is_last is True:
        rows.append(row.tolist())
        
    is_last = True
    
last_set = pd.DataFrame(data = rows, columns = test.columns)

name = 'test_WY_one_hot_encoded'
test_names.append(name)
last_set.to_csv('./data/strateg_2_addr_state/' + name + '.csv', index = False)
length.append(len(last_set.index))
print('WY')
print(last_set.shape)
import numpy as np
print(np.cumsum(length))
# Out:
# AK
# (424, 134)
# AL
# (2238, 134)
# AR
# (1273, 134)
# AZ
# (4352, 134)
# CA
# (25838, 134)
# CO
# (4409, 134)
# CT
# (2256, 134)
# DC
# (428, 134)
# DE
# (496, 134)
# FL
# (12533, 134)
# GA
# (5566, 134)
# HI
# (923, 134)
# IA
# (0, 134)
# ID
# (174, 134)
# IL
# (6051, 134)
# IN
# (2900, 134)
# KS
# (1310, 134)
# KY
# (1623, 134)
# LA
# (2013, 134)
# MA
# (3878, 134)
# MD
# (4030, 134)
# ME
# (294, 134)
# MI
# (4654, 134)
# MN
# (3206, 134)
# MO
# (2588, 134)
# MS
# (1009, 134)
# MT
# (480, 134)
# NC
# (5135, 134)
# ND
# (256, 134)
# NE
# (631, 134)
# NH
# (778, 134)
# NJ
# (5847, 134)
# NM
# (1042, 134)
# NV
# (2719, 134)
# NY
# (13274, 134)
# OH
# (5536, 134)
# OK
# (1586, 134)
# OR
# (2106, 134)
# PA
# (5836, 134)
# RI
# (719, 134)
# SC
# (1981, 134)
# SD
# (348, 134)
# TN
# (2814, 134)
# TX
# (14264, 134)
# UT
# (1497, 134)
# VA
# (4923, 134)
# VT
# (341, 134)
# WA
# (3751, 134)
# WI
# (2206, 134)
# WV
# (597, 134)
# WY
# (367, 134)
# [   424   2662   3935   8287  34125  38534  40790  41218  41714  54247
#   59813  60736  60736  60910  66961  69861  71171  72794  74807  78685
#   82715  83009  87663  90869  93457  94466  94946 100081 100337 100968
#  101746 107593 108635 111354 124628 130164 131750 133856 139692 140411
#  142392 142740 145554 159818 161315 166238 166579 170330 172536 173133
#  173500]

# %%
info = pd.DataFrame({'train_names': train_names, 'test_names': test_names})
info.to_csv('./data/strateg_2_addr_state/info.csv', index = False)

# %%
info
# Out:
#                  train_names               test_names
# 0   train_AK_one_hot_encoded  test_AK_one_hot_encoded
# 1   train_AL_one_hot_encoded  test_AL_one_hot_encoded
# 2   train_AR_one_hot_encoded  test_AR_one_hot_encoded
# 3   train_AZ_one_hot_encoded  test_AZ_one_hot_encoded
# 4   train_CA_one_hot_encoded  test_CA_one_hot_encoded
# 5   train_CO_one_hot_encoded  test_CO_one_hot_encoded
# 6   train_CT_one_hot_encoded  test_CT_one_hot_encoded
# 7   train_DC_one_hot_encoded  test_DC_one_hot_encoded
# 8   train_DE_one_hot_encoded  test_DE_one_hot_encoded
# 9   train_FL_one_hot_encoded  test_FL_one_hot_encoded
# 10  train_GA_one_hot_encoded  test_GA_one_hot_encoded
# 11  train_HI_one_hot_encoded  test_HI_one_hot_encoded
# 12  train_IA_one_hot_encoded  test_IA_one_hot_encoded
# 13  train_ID_one_hot_encoded  test_ID_one_hot_encoded
# 14  train_IL_one_hot_encoded  test_IL_one_hot_encoded
# 15  train_IN_one_hot_encoded  test_IN_one_hot_encoded
# 16  train_KS_one_hot_encoded  test_KS_one_hot_encoded
# 17  train_KY_one_hot_encoded  test_KY_one_hot_encoded
# 18  train_LA_one_hot_encoded  test_LA_one_hot_encoded
# 19  train_MA_one_hot_encoded  test_MA_one_hot_encoded
# 20  train_MD_one_hot_encoded  test_MD_one_hot_encoded
# 21  train_ME_one_hot_encoded  test_ME_one_hot_encoded
# 22  train_MI_one_hot_encoded  test_MI_one_hot_encoded
# 23  train_MN_one_hot_encoded  test_MN_one_hot_encoded
# 24  train_MO_one_hot_encoded  test_MO_one_hot_encoded
# 25  train_MS_one_hot_encoded  test_MS_one_hot_encoded
# 26  train_MT_one_hot_encoded  test_MT_one_hot_encoded
# 27  train_NC_one_hot_encoded  test_NC_one_hot_encoded
# 28  train_ND_one_hot_encoded  test_ND_one_hot_encoded
# 29  train_NE_one_hot_encoded  test_NE_one_hot_encoded
# 30  train_NH_one_hot_encoded  test_NH_one_hot_encoded
# 31  train_NJ_one_hot_encoded  test_NJ_one_hot_encoded
# 32  train_NM_one_hot_encoded  test_NM_one_hot_encoded
# 33  train_NV_one_hot_encoded  test_NV_one_hot_encoded
# 34  train_NY_one_hot_encoded  test_NY_one_hot_encoded
# 35  train_OH_one_hot_encoded  test_OH_one_hot_encoded
# 36  train_OK_one_hot_encoded  test_OK_one_hot_encoded
# 37  train_OR_one_hot_encoded  test_OR_one_hot_encoded
# 38  train_PA_one_hot_encoded  test_PA_one_hot_encoded
# 39  train_RI_one_hot_encoded  test_RI_one_hot_encoded
# 40  train_SC_one_hot_encoded  test_SC_one_hot_encoded
# 41  train_SD_one_hot_encoded  test_SD_one_hot_encoded
# 42  train_TN_one_hot_encoded  test_TN_one_hot_encoded
# 43  train_TX_one_hot_encoded  test_TX_one_hot_encoded
# 44  train_UT_one_hot_encoded  test_UT_one_hot_encoded
# 45  train_VA_one_hot_encoded  test_VA_one_hot_encoded
# 46  train_VT_one_hot_encoded  test_VT_one_hot_encoded
# 47  train_WA_one_hot_encoded  test_WA_one_hot_encoded
# 48  train_WI_one_hot_encoded  test_WI_one_hot_encoded
# 49  train_WV_one_hot_encoded  test_WV_one_hot_encoded
# 50  train_WY_one_hot_encoded  test_WY_one_hot_encoded
